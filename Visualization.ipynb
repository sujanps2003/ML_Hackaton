# %%
import pandas as pd
import numpy as np
import seaborn as sn
import matplotlib.pyplot as plt

# %%
df= pd.read_csv('cleaned_data_1.csv')
df

# %%
grouped=df.groupby('Diabetes_012')
grouped

# %%
for v,g in grouped:
    print("value",v)
    print("group",g)
    g.to_csv(f"group_{v}.csv",index=False)
# Out:
# value 0
# group         Unnamed: 0  Diabetes_012  HighBP  HighChol  BMI  Smoker  \
# 0                0             0       1         1   40       1
# 1                1             0       0         0   25       1
# 2                2             0       1         1   28       0
# 3                3             0       1         0   27       0
# 4                4             0       1         1   24       0
# ...            ...           ...     ...       ...  ...     ...
# 229774      253673             0       1         0   42       0
# 229775      253674             0       0         0   27       0
# 229776      253675             0       1         1   45       0
# 229778      253677             0       0         0   28       0
# 229779      253678             0       1         0   23       0
#
#         HeartDiseaseorAttack  PhysActivity  Fruits  Veggies  \
# 0                          0             0       0        1
# ...

# %%
df_0=pd.read_csv('group_0.csv')
df_0
# Out:
#         Unnamed: 0  Diabetes_012  HighBP  HighChol  BMI  Smoker  \
# 0                0             0       1         1   40       1
# 1                1             0       0         0   25       1
# 2                2             0       1         1   28       0
# 3                3             0       1         0   27       0
# 4                4             0       1         1   24       0
# ...            ...           ...     ...       ...  ...     ...
# 190050      253673             0       1         0   42       0
# 190051      253674             0       0         0   27       0
# 190052      253675             0       1         1   45       0
# 190053      253677             0       0         0   28       0
# 190054      253678             0       1         0   23       0
#
#         HeartDiseaseorAttack  PhysActivity  Fruits  Veggies  \
# 0                          0             0       0        1
# 1                          0             1       0        0
# ...

# %%
df_1=pd.read_csv('group_1.csv')
df_1
# Out:
#       Unnamed: 0  Diabetes_012  HighBP  HighChol  BMI  Smoker  \
# 0             64             1       1         1   27       0
# 1             81             1       1         1   33       0
# 2            193             1       1         1   34       0
# 3            236             1       1         1   33       1
# 4            275             1       1         1   32       1
# ...          ...           ...     ...       ...  ...     ...
# 4624      253528             1       1         0   34       0
# 4625      253529             1       1         0   32       1
# 4626      253566             1       0         0   24       0
# 4627      253664             1       0         1   29       1
# 4628      253666             1       1         0   23       0
#
#       HeartDiseaseorAttack  PhysActivity  Fruits  Veggies  HvyAlcoholConsump  \
# 0                        0             1       1        1                  0
# ...

# %%
df_2=pd.read_csv('group_2.csv')
df_2
# Out:
#        Unnamed: 0  Diabetes_012  HighBP  HighChol  BMI  Smoker  \
# 0               8             2       1         1   30       1
# 1              10             2       0         0   25       1
# 2              13             2       1         1   28       0
# 3              17             2       0         0   23       1
# 4              23             2       1         0   27       0
# ...           ...           ...     ...       ...  ...     ...
# 35092      253659             2       0         1   37       0
# 35093      253668             2       0         1   29       1
# 35094      253670             2       1         1   25       0
# 35095      253676             2       1         1   18       0
# 35096      253679             2       1         1   25       0
#
#        HeartDiseaseorAttack  PhysActivity  Fruits  Veggies  HvyAlcoholConsump  \
# 0                         1             0       1        1                  0
# ...

# %%
hm_0=sn.heatmap(data=df_0 ,cmap='viridis')

# %%
hm_1=sn.heatmap(data=df_1 ,cmap='viridis')

# %%
hm_2=sn.heatmap(data=df_2 ,cmap='viridis')
